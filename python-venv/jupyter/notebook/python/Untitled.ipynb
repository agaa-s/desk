# %% [markdown]
# [参考] <http://pppurple.hatenablog.com/entry/2016/02/28/213152>

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4]
y = [1,8,27,64]
plt.plot(x,y)
plt.show()

# %%
import matplotlib
matplotlib.matplotlib_fname()
# Out:
# '/home/kunihiko/agaa-s/desk/python-venv/jupyter/lib/python3.6/site-packages/matplotlib/mpl-data/matplotlibrc'

# %%
plt.scatter(x,y)
